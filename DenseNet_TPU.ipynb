# %% [markdown]
# <a href="https://colab.research.google.com/github/KeiShiba-1218/ColabNotebooks/blob/main/DenseNet_TPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DenseNet Inplementation with Colab TPU in 05 Jan 2021
# This is the inplementation of densenet with tensorflow 2.x

# %% [markdown]
# #Import modules

# %%
import os
import glob
import time
import pickle
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

print(tf.__version__)
# Out:
# 2.4.0

# %% [markdown]
# ##Preparing for using TPU
# ###Connecting to TPU server

# %%
tpu_grpc_url = "grpc://" + os.environ["COLAB_TPU_ADDR"]
tpu_cluster_resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu_grpc_url)
tf.config.experimental_connect_to_cluster(tpu_cluster_resolver)
tf.tpu.experimental.initialize_tpu_system(tpu_cluster_resolver)
strategy = tf.distribute.TPUStrategy(tpu_cluster_resolver)
# Out:
# INFO:tensorflow:Initializing the TPU system: grpc://10.74.103.242:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.74.103.242:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %% [markdown]
# ###Decorator for simplifying TPU training

# %%
from enum import Enum

class Reduction(Enum):
    NONE = 0
    SUM = 1
    MEAN = 2
    CONCAT = 3

def distributed(*reduction_flags):
    # Reduction flag is what you want the tensor returning from each TPU to do.
    def _decorator(fun):
        def per_replica_reduction(z, flag):
            if flag == Reduction.NONE:
                return z
            elif flag == Reduction.SUM:
                return strategy.reduce(tf.distribute.ReduceOp.SUM, z, axis=None)
            elif flag == Reduction.MEAN:
                return strategy.reduce(tf.distribute.ReduceOp.MEAN, z, axis=None)
            elif flag == Reduction.CONCAT:
                z_list = strategy.experimental_local_results(z)
                return tf.concat(z_list, axis=0)
            else:
                raise NotImplementedError()
        
        @tf.function
        def _decorated_fun(*args, **kwargs):
            fun_result = strategy.run(fun, args=args, kwargs=kwargs)
            if len(reduction_flags) == 0:
                assert fun_result is None
                return
            elif len(reduction_flags) == 1:
                assert type(fun_result) is not tuple and fun_result is not None
                return per_replica_reduction(fun_result, *reduction_flags)
            else:
                assert type(fun_result) is tuple
                return tuple((per_replica_reduction(fr, rf) for fr, rf in zip(fun_result, reduction_flags)))
        return _decorated_fun
    return _decorator

# %% [markdown]
# #Create dataset

# %%
def load_cifar10(batch_size):
    (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
    y_train = tf.keras.utils.to_categorical(y_train)
    y_test = tf.keras.utils.to_categorical(y_test)

    def data_augmentation(img):
        x = tf.cast(img, tf.float32) / 127.5 - 1.0 # [-1, 1]
        x = tf.image.random_flip_left_right(x)
        # padding to change size to (34, 34, 3)
        x = tf.pad(x, tf.constant([[2, 2], [2, 2], [0, 0]]), mode='REFLECT')
        x = tf.image.random_crop(x, size=[32, 32, 3])
        return x

    trainset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    trainset = trainset.map(
        lambda img, label: (data_augmentation(img), tf.cast(label, tf.float32))
    ).shuffle(4096).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

    testset = tf.data.Dataset.from_tensor_slices((x_test, y_test))
    testset = testset.map(
        lambda img, label: (tf.cast(img, tf.float32)/127.5-1.0, tf.cast(label, tf.float32))
    ).shuffle(4096).batch(batch_size).prefetch(tf.data.experimental.AUTOTUNE)

    return trainset, testset

# If you use TPU, you can use large batch size!
BATCH_SIZE = 1024
trainset, testset = load_cifar10(BATCH_SIZE)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# ##Check images

# %%
def make_grid(imgs, nrow, padding=0):
    # ndarray 4th floor tensors(images) -> image listed images
    assert imgs.ndim == 4 and nrow > 0
    batch, height, width, ch = imgs.shape
    n = nrow * (batch // nrow + np.sign(batch % nrow))
    ncol = n // nrow
    pad = np.zeros((n-batch, height, width, ch), imgs.dtype)
    x = np.concatenate([imgs, pad], axis=0)
    if padding > 0:
        x = np.pad(x, ((0, 0), (0, padding), (0, padding), (0, 0)), 
                   'constant', constant_values=(0, 0))
        height += padding
        width += padding
    x = x.reshape(ncol, nrow, height, width, ch)
    x = x.transpose([0, 2, 1, 3, 4])
    x = x.reshape(height*ncol, width*nrow, ch)
    if padding > 0:
        x = x[:(height*ncol - padding), :(width*nrow - padding), :]
    return x

def plot_images(images, nrow=10, padding=0, img_name='sample_img.png', plotting=True):
    imgs = images.numpy()
    grid = make_grid(imgs, nrow, padding)
    grid = ((grid+1)*127.5).astype(np.uint8) # [0, 255]
    plt.figure(figsize=(10, 10))
    plt.axis('off')
    plt.imshow(grid)
    plt.savefig(img_name, bbox_inches='tight', pad_inches=0.0)
    if plotting: plt.show()
    plt.close('all')

BATCH_SIZE = 1024
trainset, testset = load_cifar10(BATCH_SIZE)

temp1, temp2 = next(iter(trainset))
plot_images(temp1[:100])

# %% [markdown]
# #Create network

# %%
BATCH_SIZE = 1024

def dense_block(x, k):
        a = x
        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = Conv2D(4*k, 1)(x)
        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = Conv2D(k, kernel_size=3, strides=1, padding='same')(x)
        x = Concatenate()([x, a])
        return x

def transition_layer(x, cf):
    x = Conv2D(int(x.shape[-1]*cf), 1)(x)
    x = AveragePooling2D()(x)
    return x

def create_net(k, cf=0.5, n_blocks=[1,2,4,3]):
    '''
    k: growth rate
    cf: compression factor
    n_blocks: list of number of dense block
    '''
    inputs = Input((32, 32, 3))
    x = Conv2D(16, 1)(inputs)
    for i, n_block in enumerate(n_blocks):
        if i!=0:
            x = transition_layer(x, cf)
        for j in range(n_block):
            x = dense_block(x, k)
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(10)(x)
    return Model(inputs, outputs)

# %% [markdown]
# ##Check network summary and arcitecture

# %%
K.clear_session()

net = create_net(k=16, cf=0.5, n_blocks=[3,6,12,8])
net.summary()
tf.keras.utils.plot_model(net, 'net_graph.png', show_shapes=True)
print()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   64          input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 32, 32, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   1088        re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   9232        re_lu_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 32)   0           conv2d_2[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         concatenate[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   2112        re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 16)   9232        re_lu_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 48)   0           conv2d_4[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 48)   192         concatenate_1[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 32, 32, 48)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   3136        re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 32, 32, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   9232        re_lu_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 64)   0           conv2d_6[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 32)   2080        concatenate_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 16, 16, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 32)   128         average_pooling2d[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 16, 16, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   2112        re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 16, 16, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 16)   9232        re_lu_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 48)   0           conv2d_9[0][0]
#                                                                  average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 48)   192         concatenate_3[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 16, 16, 48)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   3136        re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 16, 16, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 16)   9232        re_lu_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 64)   0           conv2d_11[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 64)   256         concatenate_4[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 16, 16, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   4160        re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 16, 16, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 16)   9232        re_lu_11[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 80)   0           conv2d_13[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 80)   320         concatenate_5[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 16, 16, 80)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 64)   5184        re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 16, 16, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 16)   9232        re_lu_13[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 16, 16, 96)   0           conv2d_15[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 96)   384         concatenate_6[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 16, 16, 96)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 64)   6208        re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 16, 16, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 16)   9232        re_lu_15[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 16, 16, 112)  0           conv2d_17[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 112)  448         concatenate_7[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 16, 16, 112)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 64)   7232        re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 16, 16, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 16)   9232        re_lu_17[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 16, 16, 128)  0           conv2d_19[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 64)   8256        concatenate_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 8, 8, 64)     0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 8, 8, 64)     256         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 64)     4160        re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 8, 8, 64)     256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 16)     9232        re_lu_19[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 8, 8, 80)     0           conv2d_22[0][0]
#                                                                  average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 8, 8, 80)     320         concatenate_9[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 8, 8, 80)     0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 64)     5184        re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 64)     256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 8, 16)     9232        re_lu_21[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 8, 8, 96)     0           conv2d_24[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 96)     384         concatenate_10[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 8, 8, 96)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 8, 8, 64)     6208        re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 8, 64)     256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 8, 8, 16)     9232        re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8, 8, 112)    0           conv2d_26[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 112)    448         concatenate_11[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 8, 8, 112)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 64)     7232        re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 64)     256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 16)     9232        re_lu_25[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 8, 8, 128)    0           conv2d_28[0][0]
#                                                                  concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 128)    512         concatenate_12[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 8, 8, 128)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 64)     8256        re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 64)     256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 16)     9232        re_lu_27[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 8, 8, 144)    0           conv2d_30[0][0]
#                                                                  concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 144)    576         concatenate_13[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 8, 8, 144)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 64)     9280        re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 64)     256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 16)     9232        re_lu_29[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 8, 8, 160)    0           conv2d_32[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 8, 160)    640         concatenate_14[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 8, 8, 160)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 64)     10304       re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 64)     256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 16)     9232        re_lu_31[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 8, 8, 176)    0           conv2d_34[0][0]
#                                                                  concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 176)    704         concatenate_15[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 8, 8, 176)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 64)     11328       re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 64)     256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 16)     9232        re_lu_33[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 8, 8, 192)    0           conv2d_36[0][0]
#                                                                  concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 192)    768         concatenate_16[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 8, 8, 192)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 64)     12352       re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 8, 64)     256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 16)     9232        re_lu_35[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 8, 8, 208)    0           conv2d_38[0][0]
#                                                                  concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 8, 8, 208)    832         concatenate_17[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, 8, 8, 208)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 64)     13376       re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 64)     256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 16)     9232        re_lu_37[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 8, 8, 224)    0           conv2d_40[0][0]
#                                                                  concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 224)    896         concatenate_18[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 8, 8, 224)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 64)     14400       re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 64)     256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 16)     9232        re_lu_39[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 8, 8, 240)    0           conv2d_42[0][0]
#                                                                  concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 240)    960         concatenate_19[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 8, 8, 240)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 64)     15424       re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 8, 64)     256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, 8, 8, 64)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 16)     9232        re_lu_41[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 8, 8, 256)    0           conv2d_44[0][0]
#                                                                  concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 128)    32896       concatenate_20[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 4, 4, 128)    0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 4, 4, 128)    512         average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_42 (ReLU)                 (None, 4, 4, 128)    0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 64)     8256        re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 4, 4, 64)     256         conv2d_46[0][0]
# __________________________________________________________________________________________________
# re_lu_43 (ReLU)                 (None, 4, 4, 64)     0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 16)     9232        re_lu_43[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 4, 4, 144)    0           conv2d_47[0][0]
#                                                                  average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 4, 4, 144)    576         concatenate_21[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, 4, 4, 144)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 4, 4, 64)     9280        re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 4, 4, 64)     256         conv2d_48[0][0]
# __________________________________________________________________________________________________
# re_lu_45 (ReLU)                 (None, 4, 4, 64)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 4, 4, 16)     9232        re_lu_45[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 4, 4, 160)    0           conv2d_49[0][0]
#                                                                  concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 4, 4, 160)    640         concatenate_22[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, 4, 4, 160)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 4, 4, 64)     10304       re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 4, 4, 64)     256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# re_lu_47 (ReLU)                 (None, 4, 4, 64)     0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 4, 4, 16)     9232        re_lu_47[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 4, 4, 176)    0           conv2d_51[0][0]
#                                                                  concatenate_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 4, 4, 176)    704         concatenate_23[0][0]
# __________________________________________________________________________________________________
# re_lu_48 (ReLU)                 (None, 4, 4, 176)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 4, 4, 64)     11328       re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 4, 4, 64)     256         conv2d_52[0][0]
# __________________________________________________________________________________________________
# re_lu_49 (ReLU)                 (None, 4, 4, 64)     0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 4, 4, 16)     9232        re_lu_49[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 4, 4, 192)    0           conv2d_53[0][0]
#                                                                  concatenate_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 4, 4, 192)    768         concatenate_24[0][0]
# __________________________________________________________________________________________________
# re_lu_50 (ReLU)                 (None, 4, 4, 192)    0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 4, 4, 64)     12352       re_lu_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 4, 4, 64)     256         conv2d_54[0][0]
# __________________________________________________________________________________________________
# re_lu_51 (ReLU)                 (None, 4, 4, 64)     0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 4, 4, 16)     9232        re_lu_51[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 4, 4, 208)    0           conv2d_55[0][0]
#                                                                  concatenate_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 4, 4, 208)    832         concatenate_25[0][0]
# __________________________________________________________________________________________________
# re_lu_52 (ReLU)                 (None, 4, 4, 208)    0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 4, 4, 64)     13376       re_lu_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 4, 4, 64)     256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# re_lu_53 (ReLU)                 (None, 4, 4, 64)     0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 4, 4, 16)     9232        re_lu_53[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 4, 4, 224)    0           conv2d_57[0][0]
#                                                                  concatenate_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 4, 4, 224)    896         concatenate_26[0][0]
# __________________________________________________________________________________________________
# re_lu_54 (ReLU)                 (None, 4, 4, 224)    0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 4, 4, 64)     14400       re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 4, 4, 64)     256         conv2d_58[0][0]
# __________________________________________________________________________________________________
# re_lu_55 (ReLU)                 (None, 4, 4, 64)     0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 4, 4, 16)     9232        re_lu_55[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 4, 4, 240)    0           conv2d_59[0][0]
#                                                                  concatenate_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 4, 4, 240)    960         concatenate_27[0][0]
# __________________________________________________________________________________________________
# re_lu_56 (ReLU)                 (None, 4, 4, 240)    0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 4, 4, 64)     15424       re_lu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 4, 4, 64)     256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# re_lu_57 (ReLU)                 (None, 4, 4, 64)     0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 4, 4, 16)     9232        re_lu_57[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 4, 4, 256)    0           conv2d_61[0][0]
#                                                                  concatenate_27[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           2570        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 582,906
# Trainable params: 571,546
# Non-trainable params: 11,360
# __________________________________________________________________________________________________

# %% [markdown]
# #Training
# ##Check learning rate

# %%
EPOCH = 100

def set_lr(epoch, init_lr=5e-2, max_lr=1e-1, min_lr=1e-3, warm_up_period=20):
    e = epoch; w = warm_up_period
    if e<w:
        lr = (max_lr-init_lr)*np.sin(np.pi*e/(2*w)) + init_lr
    else:
        lr = (max_lr-min_lr)/2.0*np.cos((e-w)*np.pi/(EPOCH-w)) + (max_lr+min_lr)/2.0
    return lr

lrs = []
for i in range(EPOCH):
    lrs.append(set_lr(i))

plt.figure()
plt.plot(lrs)
plt.show()

# %%
K.clear_session()

BATCH_SIZE = 1024
STEPS_PER_EPOCH_TRAIN = 50000 // BATCH_SIZE + 1
STEPS_PER_EPOCH_TEST = 10000 // BATCH_SIZE + 1
EPOCH = 100

out_dir = 'out'
os.makedirs(out_dir, exist_ok=True)

with strategy.scope():
    net = create_net(k=16, cf=0.5, n_blocks=[1,2,4,3])
    opt = tf.keras.optimizers.SGD(learning_rate=1e-2, momentum=0.9)

    train_acc = tf.keras.metrics.CategoricalAccuracy()
    val_acc = tf.keras.metrics.CategoricalAccuracy()

    trainset, testset = load_cifar10(BATCH_SIZE)
    # Convert trainset & testset to send PerReplica
    trainset = strategy.experimental_distribute_dataset(trainset)
    testset = strategy.experimental_distribute_dataset(testset)

    def set_lr(epoch, init_lr=5e-2, max_lr=1e-1, min_lr=1e-3, warm_up_period=20):
        e = epoch; w = warm_up_period
        if e<w:
            lr = (max_lr-init_lr)*np.sin(np.pi*e/(2*w)) + init_lr
        else:
            lr = (max_lr-min_lr)/2.0*np.cos((e-w)*np.pi/(EPOCH-w)) + (max_lr+min_lr)/2.0
        return lr

    def loss_func(y, p):
        return -tf.reduce_sum(y*tf.math.log(p)) / BATCH_SIZE
    
    @distributed(Reduction.SUM)
    def train_on_batch(img, y):
        with tf.GradientTape() as tape:
            logits = net(img, training=True)
            p = tf.math.softmax(logits)
            loss = loss_func(y, p)
            train_acc.update_state(y, p)
        grad = tape.gradient(loss, net.trainable_weights)
        opt.apply_gradients(zip(grad, net.trainable_weights))
        return loss
    
    @distributed(Reduction.SUM)
    def test_on_batch(img, y):
        logits = net(img, training=False)
        p = tf.math.softmax(logits)
        loss = loss_func(y, p)
        val_acc.update_state(y, p)
        return loss

    data = []
    total_step = 0
    t0 = time.time()
    
    for epoch in range(EPOCH):
        t1 = time.time()
        print(f'Epoch: {str(epoch).zfill(3)}')
        train_acc.reset_states()
        val_acc.reset_states()
        opt.lr = set_lr(epoch, init_lr=5e-2, max_lr=1e-1, min_lr=1e-3, warm_up_period=20)

        for step, (img, label) in enumerate(trainset):
            train_loss = train_on_batch(img, label)
            if step%(STEPS_PER_EPOCH_TRAIN//2)==0:
                print(f'\tStep {str(total_step).zfill(7)}, train_loss: {train_loss.numpy():f}, train_acc: {train_acc.result().numpy():f}')
            total_step += 1
        
        for step, (img, label) in enumerate(testset):
            val_loss = test_on_batch(img, label)
        print(f'\tval_loss: {val_loss.numpy():f}, val_acc: {val_acc.result().numpy():f}')
        data.append([epoch, opt.lr.numpy(), train_loss.numpy(), val_loss.numpy(), train_acc.result().numpy(), val_acc.result().numpy()])

        print(f'{time.time()-t1:f}s is elapsed for epoch {str(epoch).zfill(3)}.')
    with open(f'data.pkl', 'wb') as fp: pickle.dump(data, fp)
    print(f'Train time: {(time.time()-t0)/60:f}min.')
# Out:
# Epoch: 000
# 	Step 0000000, train_loss: 2.575629, train_acc: 0.083008
# 	Step 0000024, train_loss: 1.810516, train_acc: 0.254375
# 	Step 0000048, train_loss: 1.362101, train_acc: 0.314520
# 	val_loss: 1.689856, val_acc: 0.179400
# 24.884946s is elapsed for epoch 000.
# Epoch: 001
# 	Step 0000049, train_loss: 1.616877, train_acc: 0.392578
# 	Step 0000073, train_loss: 1.502738, train_acc: 0.411992
# 	Step 0000097, train_loss: 1.186964, train_acc: 0.428920
# 	val_loss: 1.680714, val_acc: 0.182500
# 6.244961s is elapsed for epoch 001.
# Epoch: 002
# 	Step 0000098, train_loss: 1.558634, train_acc: 0.434570
# 	Step 0000122, train_loss: 1.429796, train_acc: 0.473477
# 	Step 0000146, train_loss: 1.083505, train_acc: 0.483520
# 	val_loss: 1.585877, val_acc: 0.258900
# 5.975011s is elapsed for epoch 002.
# Epoch: 003
# 	Step 0000147, train_loss: 1.321463, train_acc: 0.511719
# 	Step 0000171, train_loss: 1.328444, train_acc: 0.514727
# 	Step 0000195, train_loss: 1.012025, train_acc: 0.525520
# 	val_loss: 1.387642, val_acc: 0.330200
# 6.050399s is elapsed for epoch 003.
# Epoch: 004
# 	Step 0000196, train_loss: 1.245167, train_acc: 0.557617
# 	Step 0000220, train_loss: 1.214795, train_acc: 0.554648
# 	Step 0000244, train_loss: 0.979733, train_acc: 0.561440
# 	val_loss: 1.397593, val_acc: 0.387900
# 6.269364s is elapsed for epoch 004.
# Epoch: 005
# 	Step 0000245, train_loss: 1.186278, train_acc: 0.588867
# 	Step 0000269, train_loss: 1.076483, train_acc: 0.590820
# 	Step 0000293, train_loss: 0.875209, train_acc: 0.594200
# 	val_loss: 1.337185, val_acc: 0.408200
# 6.103394s is elapsed for epoch 005.
# Epoch: 006
# 	Step 0000294, train_loss: 1.096979, train_acc: 0.609375
# 	Step 0000318, train_loss: 1.048601, train_acc: 0.609141
# 	Step 0000342, train_loss: 0.876043, train_acc: 0.615000
# 	val_loss: 1.033158, val_acc: 0.547600
# 6.304602s is elapsed for epoch 006.
# Epoch: 007
# 	Step 0000343, train_loss: 1.012766, train_acc: 0.629883
# 	Step 0000367, train_loss: 0.969438, train_acc: 0.637031
# 	Step 0000391, train_loss: 0.802597, train_acc: 0.644040
# 	val_loss: 1.433320, val_acc: 0.484000
# 5.987622s is elapsed for epoch 007.
# Epoch: 008
# 	Step 0000392, train_loss: 0.977605, train_acc: 0.656250
# 	Step 0000416, train_loss: 0.929149, train_acc: 0.658086
# 	Step 0000440, train_loss: 0.776314, train_acc: 0.662340
# 	val_loss: 1.216984, val_acc: 0.506300
# 6.122313s is elapsed for epoch 008.
# Epoch: 009
# 	Step 0000441, train_loss: 0.941873, train_acc: 0.659180
# 	Step 0000465, train_loss: 0.894257, train_acc: 0.672109
# 	Step 0000489, train_loss: 0.786162, train_acc: 0.676920
# 	val_loss: 1.189114, val_acc: 0.530200
# 6.156951s is elapsed for epoch 009.
# Epoch: 010
# 	Step 0000490, train_loss: 0.856987, train_acc: 0.712891
# 	Step 0000514, train_loss: 0.836426, train_acc: 0.688398
# 	Step 0000538, train_loss: 0.666923, train_acc: 0.695420
# 	val_loss: 0.793706, val_acc: 0.642000
# 6.211159s is elapsed for epoch 010.
# Epoch: 011
# 	Step 0000539, train_loss: 0.764885, train_acc: 0.726562
# 	Step 0000563, train_loss: 0.770530, train_acc: 0.710234
# 	Step 0000587, train_loss: 0.652791, train_acc: 0.713120
# 	val_loss: 1.068959, val_acc: 0.588400
# 6.047812s is elapsed for epoch 011.
# Epoch: 012
# 	Step 0000588, train_loss: 0.769182, train_acc: 0.734375
# 	Step 0000612, train_loss: 0.813512, train_acc: 0.717539
# 	Step 0000636, train_loss: 0.614237, train_acc: 0.720440
# 	val_loss: 0.734400, val_acc: 0.654100
# 6.091434s is elapsed for epoch 012.
# Epoch: 013
# 	Step 0000637, train_loss: 0.766014, train_acc: 0.728516
# 	Step 0000661, train_loss: 0.722942, train_acc: 0.734219
# 	Step 0000685, train_loss: 0.594283, train_acc: 0.737500
# 	val_loss: 1.196519, val_acc: 0.563500
# 6.026503s is elapsed for epoch 013.
# Epoch: 014
# 	Step 0000686, train_loss: 0.748336, train_acc: 0.740234
# 	Step 0000710, train_loss: 0.775853, train_acc: 0.746602
# 	Step 0000734, train_loss: 0.634168, train_acc: 0.747680
# 	val_loss: 1.288491, val_acc: 0.571700
# 6.027092s is elapsed for epoch 014.
# Epoch: 015
# 	Step 0000735, train_loss: 0.710407, train_acc: 0.733398
# 	Step 0000759, train_loss: 0.676399, train_acc: 0.753984
# 	Step 0000783, train_loss: 0.591904, train_acc: 0.754560
# 	val_loss: 0.679082, val_acc: 0.713500
# 6.082968s is elapsed for epoch 015.
# Epoch: 016
# 	Step 0000784, train_loss: 0.634328, train_acc: 0.779297
# 	Step 0000808, train_loss: 0.681590, train_acc: 0.765625
# 	Step 0000832, train_loss: 0.506553, train_acc: 0.765760
# 	val_loss: 0.734496, val_acc: 0.675300
# 6.038190s is elapsed for epoch 016.
# Epoch: 017
# 	Step 0000833, train_loss: 0.641899, train_acc: 0.779297
# 	Step 0000857, train_loss: 0.631864, train_acc: 0.770703
# 	Step 0000881, train_loss: 0.481095, train_acc: 0.774220
# 	val_loss: 0.642172, val_acc: 0.719000
# 5.858697s is elapsed for epoch 017.
# Epoch: 018
# 	Step 0000882, train_loss: 0.625422, train_acc: 0.789062
# 	Step 0000906, train_loss: 0.614412, train_acc: 0.777070
# 	Step 0000930, train_loss: 0.495202, train_acc: 0.780880
# 	val_loss: 0.821653, val_acc: 0.666500
# 6.595158s is elapsed for epoch 018.
# Epoch: 019
# 	Step 0000931, train_loss: 0.663646, train_acc: 0.765625
# 	Step 0000955, train_loss: 0.586276, train_acc: 0.783359
# 	Step 0000979, train_loss: 0.500245, train_acc: 0.784040
# 	val_loss: 0.733838, val_acc: 0.707800
# 6.263267s is elapsed for epoch 019.
# Epoch: 020
# 	Step 0000980, train_loss: 0.612889, train_acc: 0.780273
# 	Step 0001004, train_loss: 0.554531, train_acc: 0.787891
# 	Step 0001028, train_loss: 0.506307, train_acc: 0.787960
# 	val_loss: 0.709545, val_acc: 0.728900
# 6.382424s is elapsed for epoch 020.
# Epoch: 021
# 	Step 0001029, train_loss: 0.540051, train_acc: 0.810547
# 	Step 0001053, train_loss: 0.551415, train_acc: 0.798945
# 	Step 0001077, train_loss: 0.457403, train_acc: 0.796940
# 	val_loss: 0.673870, val_acc: 0.715700
# 6.087029s is elapsed for epoch 021.
# Epoch: 022
# 	Step 0001078, train_loss: 0.543732, train_acc: 0.806641
# 	Step 0001102, train_loss: 0.566740, train_acc: 0.799961
# 	Step 0001126, train_loss: 0.483018, train_acc: 0.800520
# 	val_loss: 0.774538, val_acc: 0.692000
# 6.132781s is elapsed for epoch 022.
# Epoch: 023
# 	Step 0001127, train_loss: 0.583619, train_acc: 0.791016
# 	Step 0001151, train_loss: 0.550602, train_acc: 0.802578
# 	Step 0001175, train_loss: 0.427634, train_acc: 0.805460
# 	val_loss: 0.654250, val_acc: 0.727900
# 6.262933s is elapsed for epoch 023.
# Epoch: 024
# 	Step 0001176, train_loss: 0.522092, train_acc: 0.822266
# 	Step 0001200, train_loss: 0.560574, train_acc: 0.804023
# 	Step 0001224, train_loss: 0.496488, train_acc: 0.806900
# 	val_loss: 0.664586, val_acc: 0.740500
# 6.038973s is elapsed for epoch 024.
# Epoch: 025
# 	Step 0001225, train_loss: 0.535750, train_acc: 0.812500
# 	Step 0001249, train_loss: 0.525588, train_acc: 0.812813
# 	Step 0001273, train_loss: 0.465748, train_acc: 0.812320
# 	val_loss: 0.671132, val_acc: 0.725300
# 6.184845s is elapsed for epoch 025.
# Epoch: 026
# 	Step 0001274, train_loss: 0.539019, train_acc: 0.802734
# 	Step 0001298, train_loss: 0.549064, train_acc: 0.813047
# 	Step 0001322, train_loss: 0.403864, train_acc: 0.815460
# 	val_loss: 0.660680, val_acc: 0.728600
# 6.008357s is elapsed for epoch 026.
# Epoch: 027
# 	Step 0001323, train_loss: 0.503882, train_acc: 0.818359
# 	Step 0001347, train_loss: 0.560895, train_acc: 0.821523
# 	Step 0001371, train_loss: 0.434690, train_acc: 0.819400
# 	val_loss: 0.498271, val_acc: 0.778200
# 5.971607s is elapsed for epoch 027.
# Epoch: 028
# 	Step 0001372, train_loss: 0.522043, train_acc: 0.823242
# 	Step 0001396, train_loss: 0.505871, train_acc: 0.822422
# 	Step 0001420, train_loss: 0.426680, train_acc: 0.821480
# 	val_loss: 0.584669, val_acc: 0.755100
# 6.159178s is elapsed for epoch 028.
# Epoch: 029
# 	Step 0001421, train_loss: 0.466917, train_acc: 0.853516
# 	Step 0001445, train_loss: 0.430889, train_acc: 0.828906
# 	Step 0001469, train_loss: 0.430377, train_acc: 0.829300
# 	val_loss: 0.643954, val_acc: 0.753800
# 6.019009s is elapsed for epoch 029.
# Epoch: 030
# 	Step 0001470, train_loss: 0.464663, train_acc: 0.840820
# 	Step 0001494, train_loss: 0.477740, train_acc: 0.831797
# 	Step 0001518, train_loss: 0.378610, train_acc: 0.831240
# 	val_loss: 0.527045, val_acc: 0.758500
# 5.842529s is elapsed for epoch 030.
# Epoch: 031
# 	Step 0001519, train_loss: 0.450370, train_acc: 0.834961
# 	Step 0001543, train_loss: 0.422817, train_acc: 0.831719
# 	Step 0001567, train_loss: 0.366326, train_acc: 0.833540
# 	val_loss: 0.575348, val_acc: 0.774000
# 5.924442s is elapsed for epoch 031.
# Epoch: 032
# 	Step 0001568, train_loss: 0.480290, train_acc: 0.834961
# 	Step 0001592, train_loss: 0.410672, train_acc: 0.832461
# 	Step 0001616, train_loss: 0.363803, train_acc: 0.834700
# 	val_loss: 0.744010, val_acc: 0.736800
# 5.846574s is elapsed for epoch 032.
# Epoch: 033
# 	Step 0001617, train_loss: 0.457554, train_acc: 0.846680
# 	Step 0001641, train_loss: 0.472223, train_acc: 0.833711
# 	Step 0001665, train_loss: 0.400117, train_acc: 0.835420
# 	val_loss: 0.653180, val_acc: 0.747200
# 5.936692s is elapsed for epoch 033.
# Epoch: 034
# 	Step 0001666, train_loss: 0.448442, train_acc: 0.843750
# 	Step 0001690, train_loss: 0.429431, train_acc: 0.837617
# 	Step 0001714, train_loss: 0.378996, train_acc: 0.838040
# 	val_loss: 0.646310, val_acc: 0.745600
# 6.104613s is elapsed for epoch 034.
# Epoch: 035
# 	Step 0001715, train_loss: 0.423026, train_acc: 0.860352
# 	Step 0001739, train_loss: 0.457505, train_acc: 0.843164
# 	Step 0001763, train_loss: 0.354135, train_acc: 0.842600
# 	val_loss: 0.554077, val_acc: 0.763700
# 6.206812s is elapsed for epoch 035.
# Epoch: 036
# 	Step 0001764, train_loss: 0.476659, train_acc: 0.830078
# 	Step 0001788, train_loss: 0.397815, train_acc: 0.846719
# 	Step 0001812, train_loss: 0.385339, train_acc: 0.846220
# 	val_loss: 0.568569, val_acc: 0.783300
# 6.136731s is elapsed for epoch 036.
# Epoch: 037
# 	Step 0001813, train_loss: 0.437330, train_acc: 0.840820
# 	Step 0001837, train_loss: 0.400271, train_acc: 0.848164
# 	Step 0001861, train_loss: 0.379129, train_acc: 0.846780
# 	val_loss: 0.489469, val_acc: 0.795300
# 6.000040s is elapsed for epoch 037.
# Epoch: 038
# 	Step 0001862, train_loss: 0.492488, train_acc: 0.831055
# 	Step 0001886, train_loss: 0.423841, train_acc: 0.846836
# 	Step 0001910, train_loss: 0.372357, train_acc: 0.847580
# 	val_loss: 0.513111, val_acc: 0.783600
# 6.381757s is elapsed for epoch 038.
# Epoch: 039
# 	Step 0001911, train_loss: 0.465808, train_acc: 0.840820
# 	Step 0001935, train_loss: 0.371877, train_acc: 0.851797
# 	Step 0001959, train_loss: 0.331258, train_acc: 0.851840
# 	val_loss: 0.644125, val_acc: 0.777200
# 6.073110s is elapsed for epoch 039.
# Epoch: 040
# 	Step 0001960, train_loss: 0.478756, train_acc: 0.842773
# 	Step 0001984, train_loss: 0.483376, train_acc: 0.848164
# 	Step 0002008, train_loss: 0.353314, train_acc: 0.850900
# 	val_loss: 0.512651, val_acc: 0.794700
# 5.876932s is elapsed for epoch 040.
# Epoch: 041
# 	Step 0002009, train_loss: 0.423371, train_acc: 0.848633
# 	Step 0002033, train_loss: 0.376488, train_acc: 0.855937
# 	Step 0002057, train_loss: 0.306125, train_acc: 0.855360
# 	val_loss: 0.546348, val_acc: 0.776300
# 6.179751s is elapsed for epoch 041.
# Epoch: 042
# 	Step 0002058, train_loss: 0.366423, train_acc: 0.873047
# 	Step 0002082, train_loss: 0.412896, train_acc: 0.855781
# 	Step 0002106, train_loss: 0.345621, train_acc: 0.856520
# 	val_loss: 0.429619, val_acc: 0.807800
# 5.940053s is elapsed for epoch 042.
# Epoch: 043
# 	Step 0002107, train_loss: 0.353728, train_acc: 0.877930
# 	Step 0002131, train_loss: 0.425520, train_acc: 0.858164
# 	Step 0002155, train_loss: 0.299217, train_acc: 0.858980
# 	val_loss: 0.601651, val_acc: 0.798400
# 5.690450s is elapsed for epoch 043.
# Epoch: 044
# 	Step 0002156, train_loss: 0.397857, train_acc: 0.849609
# 	Step 0002180, train_loss: 0.369070, train_acc: 0.862773
# 	Step 0002204, train_loss: 0.345667, train_acc: 0.861220
# 	val_loss: 0.434308, val_acc: 0.809700
# 6.068934s is elapsed for epoch 044.
# Epoch: 045
# 	Step 0002205, train_loss: 0.381939, train_acc: 0.874023
# 	Step 0002229, train_loss: 0.374947, train_acc: 0.863437
# 	Step 0002253, train_loss: 0.330187, train_acc: 0.863380
# 	val_loss: 0.473480, val_acc: 0.796600
# 6.244069s is elapsed for epoch 045.
# Epoch: 046
# 	Step 0002254, train_loss: 0.349541, train_acc: 0.877930
# 	Step 0002278, train_loss: 0.346930, train_acc: 0.861211
# 	Step 0002302, train_loss: 0.358397, train_acc: 0.862300
# 	val_loss: 0.475585, val_acc: 0.807500
# 6.137096s is elapsed for epoch 046.
# Epoch: 047
# 	Step 0002303, train_loss: 0.344679, train_acc: 0.876953
# 	Step 0002327, train_loss: 0.409813, train_acc: 0.867383
# 	Step 0002351, train_loss: 0.317690, train_acc: 0.867340
# 	val_loss: 0.441837, val_acc: 0.789600
# 6.048787s is elapsed for epoch 047.
# Epoch: 048
# 	Step 0002352, train_loss: 0.354468, train_acc: 0.876953
# 	Step 0002376, train_loss: 0.380944, train_acc: 0.869336
# 	Step 0002400, train_loss: 0.318647, train_acc: 0.871360
# 	val_loss: 0.405924, val_acc: 0.816600
# 6.249355s is elapsed for epoch 048.
# Epoch: 049
# 	Step 0002401, train_loss: 0.364889, train_acc: 0.874023
# 	Step 0002425, train_loss: 0.354859, train_acc: 0.871250
# 	Step 0002449, train_loss: 0.333810, train_acc: 0.870600
# 	val_loss: 0.494404, val_acc: 0.814100
# 6.222918s is elapsed for epoch 049.
# Epoch: 050
# 	Step 0002450, train_loss: 0.377473, train_acc: 0.871094
# 	Step 0002474, train_loss: 0.411308, train_acc: 0.873008
# 	Step 0002498, train_loss: 0.304501, train_acc: 0.873560
# 	val_loss: 0.410395, val_acc: 0.820800
# 6.163264s is elapsed for epoch 050.
# Epoch: 051
# 	Step 0002499, train_loss: 0.339242, train_acc: 0.877930
# 	Step 0002523, train_loss: 0.337740, train_acc: 0.874219
# 	Step 0002547, train_loss: 0.298629, train_acc: 0.874580
# 	val_loss: 0.445710, val_acc: 0.812300
# 6.026704s is elapsed for epoch 051.
# Epoch: 052
# 	Step 0002548, train_loss: 0.321897, train_acc: 0.889648
# 	Step 0002572, train_loss: 0.332775, train_acc: 0.875664
# 	Step 0002596, train_loss: 0.277686, train_acc: 0.876300
# 	val_loss: 0.408937, val_acc: 0.825400
# 5.885017s is elapsed for epoch 052.
# Epoch: 053
# 	Step 0002597, train_loss: 0.359956, train_acc: 0.866211
# 	Step 0002621, train_loss: 0.335499, train_acc: 0.876953
# 	Step 0002645, train_loss: 0.332967, train_acc: 0.877460
# 	val_loss: 0.385320, val_acc: 0.826400
# 6.100255s is elapsed for epoch 053.
# Epoch: 054
# 	Step 0002646, train_loss: 0.323814, train_acc: 0.870117
# 	Step 0002670, train_loss: 0.330428, train_acc: 0.874922
# 	Step 0002694, train_loss: 0.297816, train_acc: 0.878400
# 	val_loss: 0.372248, val_acc: 0.814400
# 6.138862s is elapsed for epoch 054.
# Epoch: 055
# 	Step 0002695, train_loss: 0.324344, train_acc: 0.875977
# 	Step 0002719, train_loss: 0.350250, train_acc: 0.882578
# 	Step 0002743, train_loss: 0.304473, train_acc: 0.881380
# 	val_loss: 0.453159, val_acc: 0.818600
# 6.292325s is elapsed for epoch 055.
# Epoch: 056
# 	Step 0002744, train_loss: 0.362433, train_acc: 0.874023
# 	Step 0002768, train_loss: 0.311174, train_acc: 0.881328
# 	Step 0002792, train_loss: 0.301771, train_acc: 0.880600
# 	val_loss: 0.407979, val_acc: 0.813000
# 5.893476s is elapsed for epoch 056.
# Epoch: 057
# 	Step 0002793, train_loss: 0.349656, train_acc: 0.877930
# 	Step 0002817, train_loss: 0.328432, train_acc: 0.884922
# 	Step 0002841, train_loss: 0.270168, train_acc: 0.886300
# 	val_loss: 0.413184, val_acc: 0.830300
# 6.003540s is elapsed for epoch 057.
# Epoch: 058
# 	Step 0002842, train_loss: 0.284087, train_acc: 0.890625
# 	Step 0002866, train_loss: 0.290812, train_acc: 0.885078
# 	Step 0002890, train_loss: 0.299573, train_acc: 0.886500
# 	val_loss: 0.401357, val_acc: 0.827900
# 6.264083s is elapsed for epoch 058.
# Epoch: 059
# 	Step 0002891, train_loss: 0.344957, train_acc: 0.876953
# 	Step 0002915, train_loss: 0.295203, train_acc: 0.885664
# 	Step 0002939, train_loss: 0.264176, train_acc: 0.887400
# 	val_loss: 0.459982, val_acc: 0.836800
# 5.961929s is elapsed for epoch 059.
# Epoch: 060
# 	Step 0002940, train_loss: 0.315189, train_acc: 0.890625
# 	Step 0002964, train_loss: 0.337377, train_acc: 0.889297
# 	Step 0002988, train_loss: 0.278630, train_acc: 0.888800
# 	val_loss: 0.463002, val_acc: 0.807700
# 6.099813s is elapsed for epoch 060.
# Epoch: 061
# 	Step 0002989, train_loss: 0.312710, train_acc: 0.882812
# 	Step 0003013, train_loss: 0.286806, train_acc: 0.891250
# 	Step 0003037, train_loss: 0.244813, train_acc: 0.893220
# 	val_loss: 0.457859, val_acc: 0.821700
# 5.999677s is elapsed for epoch 061.
# Epoch: 062
# 	Step 0003038, train_loss: 0.259675, train_acc: 0.909180
# 	Step 0003062, train_loss: 0.297339, train_acc: 0.891563
# 	Step 0003086, train_loss: 0.242783, train_acc: 0.891940
# 	val_loss: 0.430247, val_acc: 0.828500
# 6.244594s is elapsed for epoch 062.
# Epoch: 063
# 	Step 0003087, train_loss: 0.293303, train_acc: 0.895508
# 	Step 0003111, train_loss: 0.280526, train_acc: 0.893750
# 	Step 0003135, train_loss: 0.235055, train_acc: 0.892560
# 	val_loss: 0.432818, val_acc: 0.823400
# 6.365544s is elapsed for epoch 063.
# Epoch: 064
# 	Step 0003136, train_loss: 0.305106, train_acc: 0.882812
# 	Step 0003160, train_loss: 0.295526, train_acc: 0.895234
# 	Step 0003184, train_loss: 0.241799, train_acc: 0.896560
# 	val_loss: 0.368734, val_acc: 0.829900
# 6.082143s is elapsed for epoch 064.
# Epoch: 065
# 	Step 0003185, train_loss: 0.268208, train_acc: 0.909180
# 	Step 0003209, train_loss: 0.263600, train_acc: 0.898281
# 	Step 0003233, train_loss: 0.205543, train_acc: 0.897260
# 	val_loss: 0.449596, val_acc: 0.830600
# 5.769378s is elapsed for epoch 065.
# Epoch: 066
# 	Step 0003234, train_loss: 0.255451, train_acc: 0.910156
# 	Step 0003258, train_loss: 0.286484, train_acc: 0.896914
# 	Step 0003282, train_loss: 0.196324, train_acc: 0.895620
# 	val_loss: 0.409163, val_acc: 0.830100
# 6.211498s is elapsed for epoch 066.
# Epoch: 067
# 	Step 0003283, train_loss: 0.293353, train_acc: 0.892578
# 	Step 0003307, train_loss: 0.297971, train_acc: 0.898203
# 	Step 0003331, train_loss: 0.205623, train_acc: 0.897940
# 	val_loss: 0.472669, val_acc: 0.824800
# 6.027661s is elapsed for epoch 067.
# Epoch: 068
# 	Step 0003332, train_loss: 0.283307, train_acc: 0.902344
# 	Step 0003356, train_loss: 0.264093, train_acc: 0.898398
# 	Step 0003380, train_loss: 0.221503, train_acc: 0.899500
# 	val_loss: 0.380035, val_acc: 0.837500
# 6.605181s is elapsed for epoch 068.
# Epoch: 069
# 	Step 0003381, train_loss: 0.275617, train_acc: 0.904297
# 	Step 0003405, train_loss: 0.268380, train_acc: 0.901484
# 	Step 0003429, train_loss: 0.239162, train_acc: 0.901900
# 	val_loss: 0.368324, val_acc: 0.839300
# 6.105679s is elapsed for epoch 069.
# Epoch: 070
# 	Step 0003430, train_loss: 0.260425, train_acc: 0.913086
# 	Step 0003454, train_loss: 0.293809, train_acc: 0.901641
# 	Step 0003478, train_loss: 0.217731, train_acc: 0.902420
# 	val_loss: 0.358729, val_acc: 0.843000
# 6.010811s is elapsed for epoch 070.
# Epoch: 071
# 	Step 0003479, train_loss: 0.262655, train_acc: 0.901367
# 	Step 0003503, train_loss: 0.233451, train_acc: 0.906055
# 	Step 0003527, train_loss: 0.217422, train_acc: 0.905300
# 	val_loss: 0.373622, val_acc: 0.838500
# 6.213289s is elapsed for epoch 071.
# Epoch: 072
# 	Step 0003528, train_loss: 0.267403, train_acc: 0.900391
# 	Step 0003552, train_loss: 0.238054, train_acc: 0.908164
# 	Step 0003576, train_loss: 0.263973, train_acc: 0.905580
# 	val_loss: 0.383718, val_acc: 0.835800
# 5.828778s is elapsed for epoch 072.
# Epoch: 073
# 	Step 0003577, train_loss: 0.260136, train_acc: 0.903320
# 	Step 0003601, train_loss: 0.270534, train_acc: 0.905781
# 	Step 0003625, train_loss: 0.192386, train_acc: 0.904120
# 	val_loss: 0.419384, val_acc: 0.835000
# 5.859019s is elapsed for epoch 073.
# Epoch: 074
# 	Step 0003626, train_loss: 0.265130, train_acc: 0.895508
# 	Step 0003650, train_loss: 0.274302, train_acc: 0.906875
# 	Step 0003674, train_loss: 0.249059, train_acc: 0.907220
# 	val_loss: 0.429424, val_acc: 0.845900
# 6.204095s is elapsed for epoch 074.
# Epoch: 075
# 	Step 0003675, train_loss: 0.233480, train_acc: 0.919922
# 	Step 0003699, train_loss: 0.199446, train_acc: 0.907031
# 	Step 0003723, train_loss: 0.241078, train_acc: 0.907580
# 	val_loss: 0.383594, val_acc: 0.843100
# 6.079074s is elapsed for epoch 075.
# Epoch: 076
# 	Step 0003724, train_loss: 0.278533, train_acc: 0.904297
# 	Step 0003748, train_loss: 0.240819, train_acc: 0.910703
# 	Step 0003772, train_loss: 0.214663, train_acc: 0.911400
# 	val_loss: 0.420655, val_acc: 0.844700
# 6.081425s is elapsed for epoch 076.
# Epoch: 077
# 	Step 0003773, train_loss: 0.255683, train_acc: 0.909180
# 	Step 0003797, train_loss: 0.260000, train_acc: 0.911250
# 	Step 0003821, train_loss: 0.217971, train_acc: 0.911260
# 	val_loss: 0.342616, val_acc: 0.848700
# 6.191251s is elapsed for epoch 077.
# Epoch: 078
# 	Step 0003822, train_loss: 0.241585, train_acc: 0.910156
# 	Step 0003846, train_loss: 0.262782, train_acc: 0.912695
# 	Step 0003870, train_loss: 0.160878, train_acc: 0.913600
# 	val_loss: 0.367391, val_acc: 0.846400
# 6.319079s is elapsed for epoch 078.
# Epoch: 079
# 	Step 0003871, train_loss: 0.251796, train_acc: 0.909180
# 	Step 0003895, train_loss: 0.260074, train_acc: 0.911836
# 	Step 0003919, train_loss: 0.181543, train_acc: 0.912560
# 	val_loss: 0.341428, val_acc: 0.848300
# 6.104590s is elapsed for epoch 079.
# Epoch: 080
# 	Step 0003920, train_loss: 0.201792, train_acc: 0.920898
# 	Step 0003944, train_loss: 0.236827, train_acc: 0.915430
# 	Step 0003968, train_loss: 0.166698, train_acc: 0.914840
# 	val_loss: 0.422992, val_acc: 0.846700
# 5.806653s is elapsed for epoch 080.
# Epoch: 081
# 	Step 0003969, train_loss: 0.257202, train_acc: 0.903320
# 	Step 0003993, train_loss: 0.238509, train_acc: 0.914492
# 	Step 0004017, train_loss: 0.224709, train_acc: 0.915120
# 	val_loss: 0.379854, val_acc: 0.848600
# 6.016115s is elapsed for epoch 081.
# Epoch: 082
# 	Step 0004018, train_loss: 0.234319, train_acc: 0.913086
# 	Step 0004042, train_loss: 0.187033, train_acc: 0.915586
# 	Step 0004066, train_loss: 0.233571, train_acc: 0.916780
# 	val_loss: 0.380421, val_acc: 0.849700
# 6.073147s is elapsed for epoch 082.
# Epoch: 083
# 	Step 0004067, train_loss: 0.223331, train_acc: 0.912109
# 	Step 0004091, train_loss: 0.206236, train_acc: 0.917578
# 	Step 0004115, train_loss: 0.212586, train_acc: 0.916180
# 	val_loss: 0.390545, val_acc: 0.848600
# 6.019837s is elapsed for epoch 083.
# Epoch: 084
# 	Step 0004116, train_loss: 0.241697, train_acc: 0.916992
# 	Step 0004140, train_loss: 0.230718, train_acc: 0.915547
# 	Step 0004164, train_loss: 0.184348, train_acc: 0.916640
# 	val_loss: 0.371620, val_acc: 0.851500
# 6.118786s is elapsed for epoch 084.
# Epoch: 085
# 	Step 0004165, train_loss: 0.211216, train_acc: 0.923828
# 	Step 0004189, train_loss: 0.197580, train_acc: 0.918828
# 	Step 0004213, train_loss: 0.161666, train_acc: 0.919480
# 	val_loss: 0.296364, val_acc: 0.851500
# 5.620734s is elapsed for epoch 085.
# Epoch: 086
# 	Step 0004214, train_loss: 0.228779, train_acc: 0.914062
# 	Step 0004238, train_loss: 0.218554, train_acc: 0.918125
# 	Step 0004262, train_loss: 0.178439, train_acc: 0.918380
# 	val_loss: 0.372139, val_acc: 0.848600
# 6.031524s is elapsed for epoch 086.
# Epoch: 087
# 	Step 0004263, train_loss: 0.206109, train_acc: 0.926758
# 	Step 0004287, train_loss: 0.243985, train_acc: 0.920078
# 	Step 0004311, train_loss: 0.175537, train_acc: 0.919960
# 	val_loss: 0.368656, val_acc: 0.848400
# 6.149309s is elapsed for epoch 087.
# Epoch: 088
# 	Step 0004312, train_loss: 0.223454, train_acc: 0.914062
# 	Step 0004336, train_loss: 0.239070, train_acc: 0.920391
# 	Step 0004360, train_loss: 0.189035, train_acc: 0.921100
# 	val_loss: 0.380802, val_acc: 0.850000
# 6.323964s is elapsed for epoch 088.
# Epoch: 089
# 	Step 0004361, train_loss: 0.236369, train_acc: 0.923828
# 	Step 0004385, train_loss: 0.246425, train_acc: 0.921562
# 	Step 0004409, train_loss: 0.191757, train_acc: 0.921720
# 	val_loss: 0.407688, val_acc: 0.848600
# 6.060060s is elapsed for epoch 089.
# Epoch: 090
# 	Step 0004410, train_loss: 0.231846, train_acc: 0.922852
# 	Step 0004434, train_loss: 0.211640, train_acc: 0.924062
# 	Step 0004458, train_loss: 0.161924, train_acc: 0.923800
# 	val_loss: 0.393574, val_acc: 0.850200
# 5.927888s is elapsed for epoch 090.
# Epoch: 091
# 	Step 0004459, train_loss: 0.199831, train_acc: 0.935547
# 	Step 0004483, train_loss: 0.204693, train_acc: 0.920508
# 	Step 0004507, train_loss: 0.190845, train_acc: 0.921100
# 	val_loss: 0.327746, val_acc: 0.851500
# 5.998450s is elapsed for epoch 091.
# Epoch: 092
# 	Step 0004508, train_loss: 0.226265, train_acc: 0.915039
# 	Step 0004532, train_loss: 0.177223, train_acc: 0.923047
# 	Step 0004556, train_loss: 0.163774, train_acc: 0.922060
# 	val_loss: 0.410286, val_acc: 0.851000
# 6.042590s is elapsed for epoch 092.
# Epoch: 093
# 	Step 0004557, train_loss: 0.230399, train_acc: 0.921875
# 	Step 0004581, train_loss: 0.188266, train_acc: 0.923828
# 	Step 0004605, train_loss: 0.194141, train_acc: 0.922600
# 	val_loss: 0.472702, val_acc: 0.852700
# 6.070555s is elapsed for epoch 093.
# Epoch: 094
# 	Step 0004606, train_loss: 0.194661, train_acc: 0.932617
# 	Step 0004630, train_loss: 0.214146, train_acc: 0.923945
# 	Step 0004654, train_loss: 0.165334, train_acc: 0.923860
# 	val_loss: 0.393713, val_acc: 0.850700
# 6.080443s is elapsed for epoch 094.
# Epoch: 095
# 	Step 0004655, train_loss: 0.186147, train_acc: 0.943359
# 	Step 0004679, train_loss: 0.226714, train_acc: 0.922969
# 	Step 0004703, train_loss: 0.173738, train_acc: 0.924460
# 	val_loss: 0.379743, val_acc: 0.851400
# 5.836847s is elapsed for epoch 095.
# Epoch: 096
# 	Step 0004704, train_loss: 0.204070, train_acc: 0.931641
# 	Step 0004728, train_loss: 0.212624, train_acc: 0.923047
# 	Step 0004752, train_loss: 0.157270, train_acc: 0.923620
# 	val_loss: 0.352320, val_acc: 0.853800
# 5.827573s is elapsed for epoch 096.
# Epoch: 097
# 	Step 0004753, train_loss: 0.204639, train_acc: 0.926758
# 	Step 0004777, train_loss: 0.231042, train_acc: 0.922383
# 	Step 0004801, train_loss: 0.181321, train_acc: 0.922820
# 	val_loss: 0.372659, val_acc: 0.852400
# 5.984658s is elapsed for epoch 097.
# Epoch: 098
# 	Step 0004802, train_loss: 0.177268, train_acc: 0.935547
# 	Step 0004826, train_loss: 0.194748, train_acc: 0.925039
# 	Step 0004850, train_loss: 0.165767, train_acc: 0.923800
# 	val_loss: 0.357291, val_acc: 0.852500
# 6.178429s is elapsed for epoch 098.
# Epoch: 099
# 	Step 0004851, train_loss: 0.201145, train_acc: 0.921875
# 	Step 0004875, train_loss: 0.229235, train_acc: 0.924531
# 	Step 0004899, train_loss: 0.154988, train_acc: 0.925060
# 	val_loss: 0.375454, val_acc: 0.853300
# 5.951145s is elapsed for epoch 099.
# Train time: 10.449643min.

# %% [markdown]
# ##Check learning curve

# %%
data = np.array(data)
epoch = data[:, 0]
lr = data[:, 1]
train_loss = data[:, 2]
val_loss = data[:, 3]
train_acc = data[:, 4]
val_acc = data[:, 5]

plt.figure()
plt.plot(epoch, train_loss, 'b', label='Training Loss')
plt.plot(epoch, val_loss, 'y', label='Validation Loss')
#plt.ylim(0.0, 1.0)
plt.legend()
plt.savefig('losses.png')
plt.show()
plt.clf()

plt.figure()
plt.plot(epoch, train_acc, 'b', label='Training Accuracy')
plt.plot(epoch, val_acc, 'y', label='Validation Accuracy')
#plt.ylim(0.75, 1.0)
plt.legend()
plt.savefig('accuracies.png')
plt.show()
plt.clf()
